# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Abrindo dados anonimos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


tv_0 = pd.read_csv("/content/drive/MyDrive/2022-2A-T05/Grupo 3/datasets/CSV/tv_0_ukn.csv", encoding="UTF-8")
tv_1 = pd.read_csv("/content/drive/MyDrive/2022-2A-T05/Grupo 3/datasets/CSV/tv_1_ukn.csv", encoding="UTF-8")
tv_2 = pd.read_csv("/content/drive/MyDrive/2022-2A-T05/Grupo 3/datasets/CSV/tv_2_ukn.csv", encoding="UTF-8")

# %% [markdown]
# # Multicolinearidade emissora 0

# %%
plt.figure(figsize=(18,10))
sns.heatmap(tv_0.corr(), annot=True, fmt=".1f");

# %% [markdown]
# # Multicolinearidade emissora 1

# %%
plt.figure(figsize=(18,10))
sns.heatmap(tv_1.corr(), annot=True, fmt=".1f");

# %% [markdown]
# # Multicolinearidade emissora 2

# %%
plt.figure(figsize=(18,8))
sns.heatmap(tv_2.corr(), annot=True, fmt=".1f");
